# %%
import findspark
findspark.init()

import time as t
import subprocess
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from pyspark.sql import functions as F
from pyspark.sql.types import *
from datetime import datetime, date, timedelta
import sys
from lib import sparkStructuredStreaming
import os
# %matplotlib inline
from matplotlib import pyplot as plt
from pyspark.sql.window import Window
import math as m

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.11:2.4.5,org.elasticsearch:elasticsearch-spark-20_2.11:7.6.2 pyspark-shell'

# %%
#"127.0.0.1:9092" (local) //"10.0.0.8:9092" (BACC)
bootstrap = "127.0.0.1:9092"
hdfs_path = "hdfs://0.0.0.0:19000"

# %%
spark = SparkSession \
            .builder \
            .appName("KafkaIEXStructuredStreamingTest") \
            .master("local[*]") \
            .getOrCreate()

sqlContext = SQLContext(spark)

# %%
hdfs_path = "hdfs://0.0.0.0:19000"
df2 = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/depot_full/20200507").orderBy(F.col("DepotId"))
df2.show(200, truncate = False)
# Out:
# +-------+-------------+------------+-----------------------------------------------------------+------------------------------------------------------------+---------------+
# |DepotId|Start-Capital|Strategy    |ISIN                                                       |Share                                                       |Symbol_Strategy|
# +-------+-------------+------------+-----------------------------------------------------------+------------------------------------------------------------+---------------+
# |1      |10000.0      |momentum10  |[FLIR, ATVI]                                               |[0.67, 0.33]                                                |[1]            |
# |2      |10000.0      |momentum60  |[FLIR, ATVI]                                               |[0.67, 0.33]                                                |[1]            |
# |3      |10000.0      |momentum120 |[FLIR, ATVI]                                               |[0.67, 0.33]                                                |[1]            |
# |4      |10000.0      |momentum300 |[FLIR, ATVI]                                               |[0.67, 0.33]                                                |[1]            |
# |5      |10000.0      |Buy and Hold|[FLIR, ATVI]                                               |[0.67, 0.33]                                                |[1]            |
# |6      |10000.0      |momentum10  |[FLIR, ATVI, KLAC, DVA, BWA]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1]            |
# |7      |10000.0      |momentum60  |[FLIR, ATVI, KLAC, DVA, BWA]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1]            |
# |8      |10000.0      |momentum120 |[FLIR, ATVI, KLAC, DVA, BWA]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1]            |
# |9      |10000.0      |momentum300 |[FLIR, ATVI, KLAC, DVA, BWA]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1]            |
# |10     |10000.0      |Buy and Hold|[FLIR, ATVI, KLAC, DVA, BWA]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1]            |
# |11     |10000.0      |momentum10  |[FLIR, ATVI, KLAC, DVA, BWA, WY, FFIV, AOS, ALGN, HOLX]    |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1]            |
# |12     |10000.0      |momentum60  |[FLIR, ATVI, KLAC, DVA, BWA, WY, FFIV, AOS, ALGN, HOLX]    |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1]            |
# |13     |10000.0      |momentum120 |[FLIR, ATVI, KLAC, DVA, BWA, WY, FFIV, AOS, ALGN, HOLX]    |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1]            |
# |14     |10000.0      |momentum300 |[FLIR, ATVI, KLAC, DVA, BWA, WY, FFIV, AOS, ALGN, HOLX]    |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1]            |
# |15     |10000.0      |Buy and Hold|[FLIR, ATVI, KLAC, DVA, BWA, WY, FFIV, AOS, ALGN, HOLX]    |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1]            |
# |16     |10000.0      |momentum10  |[ATVI, PCG]                                                |[0.67, 0.33]                                                |[5]            |
# |17     |10000.0      |momentum60  |[ATVI, PCG]                                                |[0.67, 0.33]                                                |[5]            |
# |18     |10000.0      |momentum120 |[ATVI, PCG]                                                |[0.67, 0.33]                                                |[5]            |
# |19     |10000.0      |momentum300 |[ATVI, PCG]                                                |[0.67, 0.33]                                                |[5]            |
# |20     |10000.0      |Buy and Hold|[ATVI, PCG]                                                |[0.67, 0.33]                                                |[5]            |
# |21     |10000.0      |momentum10  |[ATVI, PCG, CLX, IPGP, VRTX]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5]            |
# |22     |10000.0      |momentum60  |[ATVI, PCG, CLX, IPGP, VRTX]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5]            |
# |23     |10000.0      |momentum120 |[ATVI, PCG, CLX, IPGP, VRTX]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5]            |
# |24     |10000.0      |momentum300 |[ATVI, PCG, CLX, IPGP, VRTX]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5]            |
# |25     |10000.0      |Buy and Hold|[ATVI, PCG, CLX, IPGP, VRTX]                               |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5]            |
# |26     |10000.0      |momentum10  |[ATVI, PCG, CLX, IPGP, VRTX, REGN, HOLX, CTXS, NFLX, TTWO] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5]            |
# |27     |10000.0      |momentum60  |[ATVI, PCG, CLX, IPGP, VRTX, REGN, HOLX, CTXS, NFLX, TTWO] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5]            |
# |28     |10000.0      |momentum120 |[ATVI, PCG, CLX, IPGP, VRTX, REGN, HOLX, CTXS, NFLX, TTWO] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5]            |
# |29     |10000.0      |momentum300 |[ATVI, PCG, CLX, IPGP, VRTX, REGN, HOLX, CTXS, NFLX, TTWO] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5]            |
# |30     |10000.0      |Buy and Hold|[ATVI, PCG, CLX, IPGP, VRTX, REGN, HOLX, CTXS, NFLX, TTWO] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5]            |
# |31     |10000.0      |momentum10  |[RRC, APA]                                                 |[0.67, 0.33]                                                |[30]           |
# |32     |10000.0      |momentum60  |[RRC, APA]                                                 |[0.67, 0.33]                                                |[30]           |
# |33     |10000.0      |momentum120 |[RRC, APA]                                                 |[0.67, 0.33]                                                |[30]           |
# |34     |10000.0      |momentum300 |[RRC, APA]                                                 |[0.67, 0.33]                                                |[30]           |
# |35     |10000.0      |Buy and Hold|[RRC, APA]                                                 |[0.67, 0.33]                                                |[30]           |
# |36     |10000.0      |momentum10  |[RRC, APA, MRO, FLR, HOLX]                                 |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[30]           |
# |37     |10000.0      |momentum60  |[RRC, APA, MRO, FLR, HOLX]                                 |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[30]           |
# |38     |10000.0      |momentum120 |[RRC, APA, MRO, FLR, HOLX]                                 |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[30]           |
# |39     |10000.0      |momentum300 |[RRC, APA, MRO, FLR, HOLX]                                 |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[30]           |
# |40     |10000.0      |Buy and Hold|[RRC, APA, MRO, FLR, HOLX]                                 |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[30]           |
# |41     |10000.0      |momentum10  |[RRC, APA, MRO, FLR, HOLX, ADS, WYNN, EQT, XEC, WMB]       |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[30]           |
# |42     |10000.0      |momentum60  |[RRC, APA, MRO, FLR, HOLX, ADS, WYNN, EQT, XEC, WMB]       |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[30]           |
# |43     |10000.0      |momentum120 |[RRC, APA, MRO, FLR, HOLX, ADS, WYNN, EQT, XEC, WMB]       |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[30]           |
# |44     |10000.0      |momentum300 |[RRC, APA, MRO, FLR, HOLX, ADS, WYNN, EQT, XEC, WMB]       |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[30]           |
# |45     |10000.0      |Buy and Hold|[RRC, APA, MRO, FLR, HOLX, ADS, WYNN, EQT, XEC, WMB]       |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[30]           |
# |46     |10000.0      |momentum10  |[ATVI, HOLX]                                               |[0.67, 0.33]                                                |[1, 5]         |
# |47     |10000.0      |momentum60  |[ATVI, HOLX]                                               |[0.67, 0.33]                                                |[1, 5]         |
# |48     |10000.0      |momentum120 |[ATVI, HOLX]                                               |[0.67, 0.33]                                                |[1, 5]         |
# |49     |10000.0      |momentum300 |[ATVI, HOLX]                                               |[0.67, 0.33]                                                |[1, 5]         |
# |50     |10000.0      |Buy and Hold|[ATVI, HOLX]                                               |[0.67, 0.33]                                                |[1, 5]         |
# |51     |10000.0      |momentum10  |[ATVI, HOLX, NFLX, FAST, TTWO]                             |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5]         |
# |52     |10000.0      |momentum60  |[ATVI, HOLX, NFLX, FAST, TTWO]                             |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5]         |
# |53     |10000.0      |momentum120 |[ATVI, HOLX, NFLX, FAST, TTWO]                             |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5]         |
# |54     |10000.0      |momentum300 |[ATVI, HOLX, NFLX, FAST, TTWO]                             |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5]         |
# |55     |10000.0      |Buy and Hold|[ATVI, HOLX, NFLX, FAST, TTWO]                             |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5]         |
# |56     |10000.0      |momentum10  |[ATVI, HOLX, NFLX, FAST, TTWO, PKI, PYPL, DVA, ADBE, EBAY] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5]         |
# |57     |10000.0      |momentum60  |[ATVI, HOLX, NFLX, FAST, TTWO, PKI, PYPL, DVA, ADBE, EBAY] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5]         |
# |58     |10000.0      |momentum120 |[ATVI, HOLX, NFLX, FAST, TTWO, PKI, PYPL, DVA, ADBE, EBAY] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5]         |
# |59     |10000.0      |momentum300 |[ATVI, HOLX, NFLX, FAST, TTWO, PKI, PYPL, DVA, ADBE, EBAY] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5]         |
# |60     |10000.0      |Buy and Hold|[ATVI, HOLX, NFLX, FAST, TTWO, PKI, PYPL, DVA, ADBE, EBAY] |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5]         |
# |61     |10000.0      |momentum10  |[HOLX, FLIR]                                               |[0.67, 0.33]                                                |[1, 30]        |
# |62     |10000.0      |momentum60  |[HOLX, FLIR]                                               |[0.67, 0.33]                                                |[1, 30]        |
# |63     |10000.0      |momentum120 |[HOLX, FLIR]                                               |[0.67, 0.33]                                                |[1, 30]        |
# |64     |10000.0      |momentum300 |[HOLX, FLIR]                                               |[0.67, 0.33]                                                |[1, 30]        |
# |65     |10000.0      |Buy and Hold|[HOLX, FLIR]                                               |[0.67, 0.33]                                                |[1, 30]        |
# |66     |10000.0      |momentum10  |[HOLX, FLIR, DVN, FFIV, ALGN]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 30]        |
# |67     |10000.0      |momentum60  |[HOLX, FLIR, DVN, FFIV, ALGN]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 30]        |
# |68     |10000.0      |momentum120 |[HOLX, FLIR, DVN, FFIV, ALGN]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 30]        |
# |69     |10000.0      |momentum300 |[HOLX, FLIR, DVN, FFIV, ALGN]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 30]        |
# |70     |10000.0      |Buy and Hold|[HOLX, FLIR, DVN, FFIV, ALGN]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 30]        |
# |71     |10000.0      |momentum10  |[HOLX, FLIR, DVN, FFIV, ALGN, PKI, PYPL, EBAY, MRO, ATVI]  |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 30]        |
# |72     |10000.0      |momentum60  |[HOLX, FLIR, DVN, FFIV, ALGN, PKI, PYPL, EBAY, MRO, ATVI]  |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 30]        |
# |73     |10000.0      |momentum120 |[HOLX, FLIR, DVN, FFIV, ALGN, PKI, PYPL, EBAY, MRO, ATVI]  |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 30]        |
# |74     |10000.0      |momentum300 |[HOLX, FLIR, DVN, FFIV, ALGN, PKI, PYPL, EBAY, MRO, ATVI]  |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 30]        |
# |75     |10000.0      |Buy and Hold|[HOLX, FLIR, DVN, FFIV, ALGN, PKI, PYPL, EBAY, MRO, ATVI]  |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 30]        |
# |76     |10000.0      |momentum10  |[HOLX, PCG]                                                |[0.67, 0.33]                                                |[5, 30]        |
# |77     |10000.0      |momentum60  |[HOLX, PCG]                                                |[0.67, 0.33]                                                |[5, 30]        |
# |78     |10000.0      |momentum120 |[HOLX, PCG]                                                |[0.67, 0.33]                                                |[5, 30]        |
# |79     |10000.0      |momentum300 |[HOLX, PCG]                                                |[0.67, 0.33]                                                |[5, 30]        |
# |80     |10000.0      |Buy and Hold|[HOLX, PCG]                                                |[0.67, 0.33]                                                |[5, 30]        |
# |81     |10000.0      |momentum10  |[HOLX, PCG, EBAY, IPGP, PYPL]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5, 30]        |
# |82     |10000.0      |momentum60  |[HOLX, PCG, EBAY, IPGP, PYPL]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5, 30]        |
# |83     |10000.0      |momentum120 |[HOLX, PCG, EBAY, IPGP, PYPL]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5, 30]        |
# |84     |10000.0      |momentum300 |[HOLX, PCG, EBAY, IPGP, PYPL]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5, 30]        |
# |85     |10000.0      |Buy and Hold|[HOLX, PCG, EBAY, IPGP, PYPL]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[5, 30]        |
# |86     |10000.0      |momentum10  |[HOLX, PCG, EBAY, IPGP, PYPL, EFX, LOW, PKI, ATVI, FBHS]   |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5, 30]        |
# |87     |10000.0      |momentum60  |[HOLX, PCG, EBAY, IPGP, PYPL, EFX, LOW, PKI, ATVI, FBHS]   |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5, 30]        |
# |88     |10000.0      |momentum120 |[HOLX, PCG, EBAY, IPGP, PYPL, EFX, LOW, PKI, ATVI, FBHS]   |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5, 30]        |
# |89     |10000.0      |momentum300 |[HOLX, PCG, EBAY, IPGP, PYPL, EFX, LOW, PKI, ATVI, FBHS]   |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5, 30]        |
# |90     |10000.0      |Buy and Hold|[HOLX, PCG, EBAY, IPGP, PYPL, EFX, LOW, PKI, ATVI, FBHS]   |[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[5, 30]        |
# |91     |10000.0      |momentum10  |[HOLX, ATVI]                                               |[0.67, 0.33]                                                |[1, 5, 30]     |
# |92     |10000.0      |momentum60  |[HOLX, ATVI]                                               |[0.67, 0.33]                                                |[1, 5, 30]     |
# |93     |10000.0      |momentum120 |[HOLX, ATVI]                                               |[0.67, 0.33]                                                |[1, 5, 30]     |
# |94     |10000.0      |momentum300 |[HOLX, ATVI]                                               |[0.67, 0.33]                                                |[1, 5, 30]     |
# |95     |10000.0      |Buy and Hold|[HOLX, ATVI]                                               |[0.67, 0.33]                                                |[1, 5, 30]     |
# |96     |10000.0      |momentum10  |[HOLX, ATVI, EBAY, PYPL, PKI]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5, 30]     |
# |97     |10000.0      |momentum60  |[HOLX, ATVI, EBAY, PYPL, PKI]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5, 30]     |
# |98     |10000.0      |momentum120 |[HOLX, ATVI, EBAY, PYPL, PKI]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5, 30]     |
# |99     |10000.0      |momentum300 |[HOLX, ATVI, EBAY, PYPL, PKI]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5, 30]     |
# |100    |10000.0      |Buy and Hold|[HOLX, ATVI, EBAY, PYPL, PKI]                              |[0.33, 0.27, 0.2, 0.13, 0.07]                               |[1, 5, 30]     |
# |101    |10000.0      |momentum10  |[HOLX, ATVI, EBAY, PYPL, PKI, FLIR, FAST, FFIV, ORLY, NFLX]|[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5, 30]     |
# |102    |10000.0      |momentum60  |[HOLX, ATVI, EBAY, PYPL, PKI, FLIR, FAST, FFIV, ORLY, NFLX]|[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5, 30]     |
# |103    |10000.0      |momentum120 |[HOLX, ATVI, EBAY, PYPL, PKI, FLIR, FAST, FFIV, ORLY, NFLX]|[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5, 30]     |
# |104    |10000.0      |momentum300 |[HOLX, ATVI, EBAY, PYPL, PKI, FLIR, FAST, FFIV, ORLY, NFLX]|[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5, 30]     |
# |105    |10000.0      |Buy and Hold|[HOLX, ATVI, EBAY, PYPL, PKI, FLIR, FAST, FFIV, ORLY, NFLX]|[0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.05, 0.04, 0.02]|[1, 5, 30]     |
# +-------+-------------+------------+-----------------------------------------------------------+------------------------------------------------------------+---------------+

# %%
r = sparkStructuredStreaming.realtime()
day = date(2020,5,29)
sandbox = True
commission = 0.006
startCap = 10000.0

r.realtime(startCap, day, sandbox, commission, sqlContext)
# Out:
# [*********************100%***********************]  456 of 456 completed
# {'value': 9999.003756087528, 'date': '2020-06-02T09:55:47', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 10160.515229370612, 'date': '2020-06-02T09:56:22', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9765.656142320833, 'date': '2020-06-02T09:56:58', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9757.778221582232, 'date': '2020-06-02T09:57:38', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9557.112646423488, 'date': '2020-06-02T09:58:15', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9533.356557570965, 'date': '2020-06-02T09:58:53', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9407.012574378736, 'date': '2020-06-02T09:59:30', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9651.667661857278, 'date': '2020-06-02T10:00:10', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9494.44818111838, 'date': '2020-06-02T10:01:04', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9521.313604642917, 'date': '2020-06-02T10:01:46', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9468.319044835678, 'date': '2020-06-02T10:02:24', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9281.452077122738, 'date': '2020-06-02T10:03:02', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9273.724852216497, 'date': '2020-06-02T10:03:39', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9414.527469586159, 'date': '2020-06-02T10:04:16', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9437.924831924207, 'date': '2020-06-02T10:04:55', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9238.68013998448, 'date': '2020-06-02T10:05:31', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9267.604444919403, 'date': '2020-06-02T10:06:09', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9462.192821328561, 'date': '2020-06-02T10:06:48', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9287.024711044662, 'date': '2020-06-02T10:07:25', 'depotid': '20200602'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e26f59422593> in <module>
#       5 startCap = 10000.0
#       6
# ----> 7 r.realtime(startCap, day, sandbox, commission, sqlContext)
#
# ~\RAMBO\kafka_spark_python\lib\sparkStructuredStreaming.py in realtime(self, startCap, day, sandbox, commission, sqlContext)
#    2046
#    2047             depot = self.realtime_loop(value, date, moneyForInvesting_list, moneyInStocks_list, stocksOwned,\
# -> 2048                                                trades_total, symbol, share, commission, strategy, sqlContext, directory)
#    2049
#    2050             value, date, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total, cash = depot
#
# ~\RAMBO\kafka_spark_python\lib\sparkStructuredStreaming.py in realtime_loop(self, value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total, symbol, share, commission, strategy, sqlContext, directory)
#    1967             # filter out right symbol, get latest price
#    1968             df_pos = strategy[0](df, symbol[i],strategy[2])
# -> 1969             rows = df_pos.collect()[0]
#    1970             datetime[i] = rows.Datetime
#    1971             # rows[0][1] is current price of stock, rows[0][3] is position
#
# c:\spark\python\pyspark\sql\dataframe.py in collect(self)
#     532         """
#     533         with SCCallSiteSync(self._sc) as css:
# --> 534             sock_info = self._jdf.collectToPython()
#     535         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     536
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\anaconda\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
