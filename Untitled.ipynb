# %%
import findspark
findspark.init()

import time as t
import subprocess
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from pyspark.sql import functions as F
from pyspark.sql.types import *
from datetime import datetime, date, timedelta
import sys
from lib import sparkStructuredStreaming
import os
# %matplotlib inline
from matplotlib import pyplot as plt
from pyspark.sql.window import Window
import math as m

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.11:2.4.5,org.elasticsearch:elasticsearch-spark-20_2.11:7.6.2 pyspark-shell'

# %%
#"127.0.0.1:9092" (local) //"10.0.0.8:9092" (BACC)
bootstrap = "127.0.0.1:9092"
hdfs_path = "hdfs://0.0.0.0:19000"

# %%
spark = SparkSession \
            .builder \
            .appName("KafkaIEXStructuredStreamingTest") \
            .master("local[*]") \
            .getOrCreate()

sqlContext = SQLContext(spark)

# %%
hdfs_path = "hdfs://0.0.0.0:19000"
performance_best = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/performance_full/20200526").orderBy(F.col("DepotId"))
performance_best.show(200)
# Out:
# +-------+--------+-----+----+-------------+-------+----------+----------+------+--------------------+------------------+------------+--------------------+
# |DepotId|   Value|Alpha|Beta|Start-Capital| Profit|Start-Date|  End-Date|Trades|Performance_Strategy|Performance_S&P500|Value_S&P500|Start-Capital_S&P500|
# +-------+--------+-----+----+-------------+-------+----------+----------+------+--------------------+------------------+------------+--------------------+
# |      1| 10089.7| null|null|      10000.0|   89.7|2020-05-26|2020-05-26|   262|                 0.9|             -1.05|      9895.0|             10000.0|
# |      2|10103.25| null|null|      10000.0| 103.25|2020-05-26|2020-05-26|   170|                1.03|             -1.05|      9895.0|             10000.0|
# |      3| 9911.87| null|null|      10000.0| -88.13|2020-05-26|2020-05-26|    87|               -0.88|             -1.05|      9895.0|             10000.0|
# |      4| 9417.01| null|null|      10000.0|-582.99|2020-05-26|2020-05-26|     5|               -5.83|             -1.05|      9895.0|             10000.0|
# |      5| 9792.25| null|null|      10000.0|-207.75|2020-05-26|2020-05-26|   940|               -2.08|             -1.05|      9895.0|             10000.0|
# |      6| 9728.93| null|null|      10000.0|-271.07|2020-05-26|2020-05-26|   805|               -2.71|             -1.05|      9895.0|             10000.0|
# |      7|10284.76| null|null|      10000.0| 284.76|2020-05-26|2020-05-26|   334|                2.85|             -1.05|      9895.0|             10000.0|
# |      8| 9815.01| null|null|      10000.0|-184.99|2020-05-26|2020-05-26|    14|               -1.85|             -1.05|      9895.0|             10000.0|
# |      9| 9561.92| null|null|      10000.0|-438.08|2020-05-26|2020-05-26|  1236|               -4.38|             -1.05|      9895.0|             10000.0|
# |     10|10063.92| null|null|      10000.0|  63.92|2020-05-26|2020-05-26|   847|                0.64|             -1.05|      9895.0|             10000.0|
# |     11|10484.78| null|null|      10000.0| 484.78|2020-05-26|2020-05-26|   380|                4.85|             -1.05|      9895.0|             10000.0|
# |     12|10005.27| null|null|      10000.0|   5.27|2020-05-26|2020-05-26|    24|                0.05|             -1.05|      9895.0|             10000.0|
# |     76| 9417.01| null|null|      10000.0|-582.99|2020-05-26|2020-05-26|     5|               -5.83|             -1.05|      9895.0|             10000.0|
# |     77| 9792.25| null|null|      10000.0|-207.75|2020-05-26|2020-05-26|   940|               -2.08|             -1.05|      9895.0|             10000.0|
# |     78| 9728.93| null|null|      10000.0|-271.07|2020-05-26|2020-05-26|   805|               -2.71|             -1.05|      9895.0|             10000.0|
# |     79|10284.76| null|null|      10000.0| 284.76|2020-05-26|2020-05-26|   334|                2.85|             -1.05|      9895.0|             10000.0|
# |     80| 9815.01| null|null|      10000.0|-184.99|2020-05-26|2020-05-26|    14|               -1.85|             -1.05|      9895.0|             10000.0|
# |     81| 9561.92| null|null|      10000.0|-438.08|2020-05-26|2020-05-26|  1236|               -4.38|             -1.05|      9895.0|             10000.0|
# |     82|10063.92| null|null|      10000.0|  63.92|2020-05-26|2020-05-26|   847|                0.64|             -1.05|      9895.0|             10000.0|
# |     83|10484.78| null|null|      10000.0| 484.78|2020-05-26|2020-05-26|   380|                4.85|             -1.05|      9895.0|             10000.0|
# |     84|10005.27| null|null|      10000.0|   5.27|2020-05-26|2020-05-26|    24|                0.05|             -1.05|      9895.0|             10000.0|
# +-------+--------+-----+----+-------------+-------+----------+----------+------+--------------------+------------------+------------+--------------------+

# %%
r = sparkStructuredStreaming.realtime()
day = date(2020,5,5)
sandbox = True
commission = 0.006
startCap = 10000.0

r.realtime(startCap, day, sandbox, commission, sqlContext)
# Out:
# [*********************100%***********************]  456 of 456 completed
# [*********************100%***********************]  456 of 456 completed
# C:\Users\LEGLES\anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# {'value': 9997.328015645062, 'date': '2020-06-01T12:48:07', 'depotid': '20200601'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 9923.14080818177, 'date': '2020-06-01T12:48:52', 'depotid': '20200601'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 10117.575483632789, 'date': '2020-06-01T12:49:41', 'depotid': '20200601'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# {'value': 10109.736987485303, 'date': '2020-06-01T12:50:32', 'depotid': '20200601'}
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3ce14d6daa6c> in <module>
#       5 startCap = 10000.0
#       6
# ----> 7 r.realtime(startCap, day, sandbox, commission, sqlContext)
#
# ~\RAMBO\kafka_spark_python\lib\sparkStructuredStreaming.py in realtime(self, startCap, day, sandbox, commission, sqlContext)
#    2044
#    2045             depot = self.realtime_loop(value, date, moneyForInvesting_list, moneyInStocks_list, stocksOwned,\
# -> 2046                                                trades_total, symbol, share, commission, strategy, sqlContext, directory)
#    2047
#    2048             value, date, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total, cash = depot
#
# ~\RAMBO\kafka_spark_python\lib\sparkStructuredStreaming.py in realtime_loop(self, value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total, symbol, share, commission, strategy, sqlContext, directory)
#    1965             # filter out right symbol, get latest price
#    1966             df_pos = strategy[0](df, symbol[i],strategy[2])
# -> 1967             rows = df_pos.collect()[0]
#    1968             datetime[i] = rows.Datetime
#    1969             # rows[0][1] is current price of stock, rows[0][3] is position
#
# c:\spark\python\pyspark\sql\dataframe.py in collect(self)
#     532         """
#     533         with SCCallSiteSync(self._sc) as css:
# --> 534             sock_info = self._jdf.collectToPython()
#     535         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     536
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\anaconda\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
