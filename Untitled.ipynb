# %%
import findspark
findspark.init()

import time as t
import subprocess
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from pyspark.sql import functions as F
from pyspark.sql.types import *
import datetime
import sys
from lib import sparkStructuredStreaming
import os
# %matplotlib inline
from matplotlib import pyplot as plt
from pyspark.sql.window import Window
import math as m

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.11:2.4.5,org.elasticsearch:elasticsearch-spark-20_2.11:7.6.2 pyspark-shell'

# %%
#"127.0.0.1:9092" (local) //"10.0.0.8:9092" (BACC)
bootstrap = "127.0.0.1:9092"

# %%
spark = SparkSession \
            .builder \
            .appName("KafkaIEXStructuredStreaming2") \
            .master("local[*]") \
            .getOrCreate()

sqlContext = SQLContext(spark)

# %%
def write_producer_batch(symbol):
    txt = ":loop \n"
    jar = "java -jar iex_kafka_producer-jar-with-dependencies.jar \"%s\" \"127.0.0.1:9092\" \"1\" false \n"
    for symbol in symbol:
        txt += jar % (symbol)
    txt += "timeout /t 10 \ngoto loop"
    
    with open("producer.cmd", "w") as f:
        f.write(txt)

# %%
from elasticsearch import Elasticsearch
def realtime(symbol, share, startCap, commission, strategy, index, sqlContext):
    
    subprocess.call(['start_stream.bat'])
    r = sparkStructuredStreaming.realtime()
    es=Elasticsearch([{'host':'localhost','port':9200}])
    # compare momentum strategy with buy and hold
    strategy_b = [r.buy_and_hold,"buyAndHold",10]
    
    if(startCap == None):
        pass
    
    else:
        # initialize both strategys
        init_strategy = r.realtime_init(symbol, share, startCap, commission, strategy, sqlContext)
        init_b = r.realtime_init(symbol, share, startCap, commission, strategy_b, sqlContext)
        value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total = init_strategy
        value_b, datetime_b, moneyForInvesting_list_b, moneyInStocks_list_b, stocksOwned_b, trades_total_b = init_b
        
        keys = ["value", "datetime", "moneyForInvesting_list", "moneyInStocks_list", "stocksOwned", "trades_total"]
        vals = [value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total]
        strategy_dict = dict(zip(keys,vals))
        res = es.index(index=index, body=strategy_dict)
            
        vals_bnh = [value_b, datetime_b, moneyForInvesting_list_b, moneyInStocks_list_b, stocksOwned_b, trades_total_b]
        bnh_dict = dict(zip(keys,vals_bnh))
        res = es.index(index="trading_bnh", body=bnh_dict)
        
    while(True):
        last_datetime = datetime[0]
        # update depot and stocksOwned in loop until break
        depot_strategy = r.realtime_loop(value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned,\
                                           trades_total, symbol, share, commission, strategy, sqlContext)
        depot_b = r.realtime_loop(value_b, datetime_b, moneyForInvesting_list_b, moneyInStocks_list_b, stocksOwned_b,\
                                      trades_total_b, symbol, share, commission, strategy_b, sqlContext)
                
        value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total = depot_strategy
        value_b, datetime_b, moneyForInvesting_list_b, moneyInStocks_list_b, stocksOwned_b, trades_total_b = depot_b
            
        current_datetime = datetime[0]
        if(last_datetime == current_datetime):
            print("no new data")
            continue
        else:
            print(datetime[0],value,value_b)
            # write values into elasticsearch for visualisation
            keys = ["value", "datetime", "moneyForInvesting_list", "moneyInStocks_list", "stocksOwned", "trades_total"]
            vals = [value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total]
            strategy_dict = dict(zip(keys,vals))
            res = es.index(index=index, body=strategy_dict)
            
            vals_bnh = [value_b, datetime_b, moneyForInvesting_list_b, moneyInStocks_list_b, stocksOwned_b, trades_total_b]
            bnh_dict = dict(zip(keys,vals_bnh))
            res = es.index(index="trading_bnh", body=bnh_dict)

# %%
r = sparkStructuredStreaming.realtime()

# same set up as in backtesting

startCap = 10000.0
commission = 0.002
index = "trading_momentum"
# choose momentum which worked best in backtesting
momentum_str = [r.momentum,"momentum",10]

symbol = ["AAPL"]
share = [1.0]
write_producer_batch(symbol)

realtime(symbol, share, startCap, commission, momentum_str, index, sqlContext)
# Out:
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# no new data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-36c4e279c1b2> in <module>
#      13 write_producer_batch(symbol)
#      14
# ---> 15 realtime(symbol, share, startCap, commission, momentum_str, index, sqlContext)
#
# <ipython-input-59-d2b0f8dccf9d> in realtime(symbol, share, startCap, commission, strategy, index, sqlContext)
#      31         # update depot and stocksOwned in loop until break
#      32         depot_strategy = r.realtime_loop(value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned,\
# ---> 33                                            trades_total, symbol, share, commission, strategy, sqlContext)
#      34         depot_b = r.realtime_loop(value_b, datetime_b, moneyForInvesting_list_b, moneyInStocks_list_b, stocksOwned_b,\
#      35                                       trades_total_b, symbol, share, commission, strategy_b, sqlContext)
#
# ~\RAMBO\kafka_spark_python\lib\sparkStructuredStreaming.py in realtime_loop(self, value, datetime, moneyForInvesting_list, moneyInStocks_list, stocksOwned, trades_total, symbol, share, commission, strategy, sqlContext)
#    1090         -------
#    1091         value : value of depot = moneyInvested + moneyFree
# -> 1092         datetime : latest time when stock was bought/sold
#    1093         moneyForInvesting_list : list of free money for each stock
#    1094         moneyInStocks_list : list of invested money for each stock
#
# c:\spark\python\pyspark\sql\readwriter.py in load(self, path, format, schema, **options)
#     164         self.options(**options)
#     165         if isinstance(path, basestring):
# --> 166             return self._df(self._jreader.load(path))
#     167         elif path is not None:
#     168             if type(path) != list:
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# c:\spark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\anaconda\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
