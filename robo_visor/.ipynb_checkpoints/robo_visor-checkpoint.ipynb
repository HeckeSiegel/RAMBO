# %%
import findspark
findspark.init()

import time as t
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from pyspark.sql import functions as F
from pyspark.sql.types import *
from datetime import datetime, timedelta, date
import sys
from lib import sparkStructuredStreaming
import os
# %matplotlib inline
from matplotlib import pyplot as plt
from pyspark.sql.window import Window
import math as m
import pandas as pd

# %% [markdown]
# ### Set-up to stream from Kafka topic + read and write from/to Elasticsearch

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.11:2.4.5,org.elasticsearch:elasticsearch-spark-20_2.11:7.6.2 pyspark-shell'

# %%
#"127.0.0.1:9092" (local) //"10.0.0.8:9092" (BACC)
bootstrap = "127.0.0.1:9092"
hdfs_path = "hdfs://0.0.0.0:19000"

# %%
spark = SparkSession \
            .builder \
            .appName("KafkaIEXStructuredStreamingRobovisor") \
            .master("local[*]") \
            .getOrCreate()

sqlContext = SQLContext(spark)

# %% [markdown]
# ## 1. Backtesting

# %%
b = sparkStructuredStreaming.backtest()
start = date(2020,6,9)
end = date(2020,6,9)

#strategy looks at last 10,120,500... minutes to calculate average
strategy_momentum = ["momentum",60,120]

# granularity of historical data
interval_momentum="1m"

#start capital
startCap = 10000.0
startCap_market = startCap

# regulatory trading fee
commission = 0.006

# risk free market return, assumed here 0.1% but is not really clear
risk_free = 0.001

# parameters to find stock symbols
n_stock = [2]
period = [2]

best_of = 5
    
b.full_backtest(startCap, startCap_market, commission, risk_free, strategy_momentum, interval_momentum, start, end, period, n_stock, hdfs_path, sqlContext, best_of, "static_no_best")
# Out:
# [*********************100%***********************]  456 of 456 completed
# [*********************100%***********************]  456 of 456 completed
# [*********************100%***********************]  456 of 456 completed
# [*********************100%***********************]  1 of 1 completed

# %%
per_comp = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/performance_full/20200507").toPandas()
depot_comp = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/depot_full/20200507").toPandas()
perf_sim = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/performance_best").toPandas()
depot_sim = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/depot_best").toPandas()

# %% [markdown]
# ## Compare performance of different strategies on May 7th

# %%
df_perf = per_comp[["DepotId","Value","Alpha","Beta","Start-Capital","Profit","Trades","Performance_Strategy","Performance_S&P500"]].sort_values(by=['Performance_Strategy'],ascending=False)
df_perf = df_perf.rename(columns={"Value":"Value [$]","Start-Capital":"Start Capital [$]", "Profit":"Profit [$]", "Performance_Strategy":"Performance [%]","Performance_S&P500":"Market [%]"})
df_perf.reset_index(inplace=True)
df_perf_pretty = df_perf.drop(columns=["index","DepotId"])
df_perf_pretty
# Out:
#      Value [$]  Alpha  Beta  Start Capital [$]  Profit [$]  Trades  \
# 0     10656.87   6.75  0.64            10000.0      656.87      61
# 1     10520.94   5.40  0.65            10000.0      520.94      27
# 2     10178.96   2.09  1.03            10000.0      178.96       3
# 3     10115.13   1.31  0.56            10000.0      115.13     222
# 4     10103.78   1.22  0.64            10000.0      103.78      54
# ..         ...    ...   ...                ...         ...     ...
# 100    9322.48  -6.51  0.90            10000.0     -677.52    1383
# 101    9304.73  -6.67  0.97            10000.0     -695.27    1566
# 102    9267.40  -7.13  0.67            10000.0     -732.60     944
# 103    9203.21  -7.73  0.81            10000.0     -796.79    1334
# 104    9201.59  -7.79  0.69            10000.0     -798.41    1302
#
#      Performance [%]  Market [%]
# 0               6.57       -0.29
# 1               5.21       -0.29
# 2               1.79       -0.29
# 3               1.15       -0.29
# 4               1.04       -0.29
# ..               ...         ...
# 100            -6.78       -0.29
# 101            -6.95       -0.29
# 102            -7.33       -0.29
# 103            -7.97       -0.29
# 104            -7.98       -0.29
#
# [105 rows x 8 columns]

# %%
merged = df_perf.merge(depot_comp, how="left", on="DepotId")[["DepotId","Strategy","ISIN","Share"]]
merged = merged.rename(columns={"Share":"Share [%]"})
merged[["Strategy","ISIN","Share [%]"]]
# Out:
#          Strategy                                               ISIN  \
# 0      momentum60                                       [HOLX, FLIR]
# 1     momentum120                                       [HOLX, FLIR]
# 2    Buy and Hold                                       [FLIR, ATVI]
# 3      momentum10                                       [HOLX, FLIR]
# 4      momentum60                                       [HOLX, ATVI]
# ..            ...                                                ...
# 100    momentum10  [FLIR, ATVI, KLAC, DVA, BWA, WY, FFIV, AOS, AL...
# 101    momentum10  [HOLX, FLIR, DVN, FFIV, ALGN, PKI, PYPL, EBAY,...
# 102    momentum10  [ATVI, PCG, CLX, IPGP, VRTX, REGN, HOLX, CTXS,...
# 103    momentum10  [HOLX, PCG, EBAY, IPGP, PYPL, EFX, LOW, PKI, A...
# 104    momentum10  [ATVI, HOLX, NFLX, FAST, TTWO, PKI, PYPL, DVA,...
#
#                                              Share [%]
# 0                                         [0.67, 0.33]
# 1                                         [0.67, 0.33]
# 2                                         [0.67, 0.33]
# 3                                         [0.67, 0.33]
# 4                                         [0.67, 0.33]
# ..                                                 ...
# 100  [0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.0...
# 101  [0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.0...
# 102  [0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.0...
# 103  [0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.0...
# 104  [0.18, 0.16, 0.15, 0.13, 0.11, 0.09, 0.07, 0.0...
#
# [105 rows x 3 columns]

# %% [markdown]
# ## Simulate Trading from May 11th - June 3rd by chossing the strategy which worked best the day before

# %%
performance_best = sqlContext.read.format('parquet').load(hdfs_path+"/backtest/performance_best").orderBy("DepotId")
performance_best_col = performance_best.collect()
n = len(performance_best_col)
start_vals = performance_best_col[0]

date_list = [(start_vals['Start-Date']-timedelta(days=1)).strftime("%Y-%m-%d")]
trades = [0, 0]
performance = [start_vals['Start-Capital']]
performance_snp = [start_vals['Start-Capital_S&P500']]

for row in performance_best_col:
    date_list.append(row['Start-Date'].strftime("%Y-%m-%d"))
    performance.append(row["Value"])
    performance_snp.append(row["Value_S&P500"]) 
    trades.append(row["Trades"])

trades_daily = [trades[i]-trades[i-1] for i in range(1,len(trades))] 
plt.figure(figsize=[15,7])

plt.plot(date_list,performance,'b',label="Depot")
plt.plot(date_list,performance_snp,'g', label="Market (normalized to depot)")
plt.grid()
plt.xlabel("Time")
plt.ylabel("Value in $")
plt.legend()
plt.title("Trading Simulation")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=[15,3])
plt.grid()
plt.xlabel("Time")
plt.ylabel("Daily trades")
plt.xticks(rotation=45)
plt.bar(date_list, trades_daily, width = -1, align = "edge")
plt.show()

# %%
perf_sim_pretty = perf_sim[["DepotId","Value","Alpha","Beta","Start-Capital","Profit","Start-Date","Performance_Strategy","Performance_S&P500"]].sort_values(by=['Start-Date'],ascending=True)
perf_sim_pretty = perf_sim_pretty.rename(columns={"Value":"Value [$]","Start-Capital":"Start Capital [$]","Start-Date":"Day", "Profit":"Profit [$]", "Performance_Strategy":"Performance [%]","Performance_S&P500":"Market [%]"})
perf_sim_pretty
# Out:
#     DepotId  Value [$]  Alpha  Beta  Start Capital [$]  Profit [$]  \
# 7         1   10160.58  -0.21  1.80           10000.00      160.58
# 3         2   10075.65   2.40  1.37           10160.58      -84.93
# 10        3   10049.17  -0.10  0.11           10075.65      -26.48
# 14        4   10029.27  -0.62  0.22           10049.17      -19.90
# 6         5   10165.37   0.06  1.00           10029.27      136.10
# 0         6   10409.53   0.96  2.19           10165.37      244.16
# 9         7   10130.08  -1.62  1.74           10409.53     -279.45
# 1         8    9849.66  -2.96  0.55           10130.08     -280.42
# 18        9   10502.50    NaN   NaN            9849.66      652.84
# 19       10   10934.73    NaN   NaN           10502.50      432.23
# 16       11   10715.76    NaN   NaN           10934.73     -218.97
# 17       12   10665.14    NaN   NaN           10715.76      -50.62
# 2        13    9669.62  -8.99  0.78           10665.14     -995.52
# 8        14    9323.38  -4.26  0.73            9669.62     -346.24
# 13       15    9279.94  -1.68  1.45            9323.38      -43.44
# 20       16    9543.13    NaN   NaN            9279.94      263.19
# 11       17    9904.99   3.35  0.83            9543.13      361.86
# 5        18    9571.37  -3.37  0.70            9904.99     -333.62
# 15       19    8432.33 -12.67  1.58            9571.37    -1139.04
# 4        20    8587.74   0.72  1.41            8432.33      155.41
# 12       21    9005.63   4.10  1.87            8587.74      417.89
#
#            Day  Performance [%]  Market [%]
# 7   2020-05-11             1.61        1.01
# 3   2020-05-12            -0.84       -2.36
# 10  2020-05-13            -0.26       -1.50
# 14  2020-05-14            -0.20        1.89
# 6   2020-05-15             1.36        1.30
# 0   2020-05-18             2.40        0.66
# 9   2020-05-19            -2.68       -0.61
# 1   2020-05-20            -2.77        0.34
# 18  2020-05-21             6.63       -0.72
# 19  2020-05-22             4.12        0.28
# 16  2020-05-26            -2.00       -1.05
# 17  2020-05-27            -0.47        0.49
# 2   2020-05-28            -9.33       -0.44
# 8   2020-05-29            -3.58        0.93
# 13  2020-06-01            -0.47        0.84
# 20  2020-06-02             2.84        0.46
# 11  2020-06-03             3.79        0.53
# 5   2020-06-04            -3.37        0.00
# 15  2020-06-05           -11.90        0.49
# 4   2020-06-08             1.84        0.80
# 12  2020-06-09             4.87        0.41

# %%
depot_sim_pretty = depot_sim[["DepotId","Strategy","ISIN","Share"]].sort_values(by=['DepotId'],ascending=True)
depot_sim_pretty = depot_sim_pretty.rename(columns={"Share":"Share [%]"})
depot_sim_pretty
# Out:
#     DepotId      Strategy          ISIN   Share [%]
# 12        1   momentum120    [LNC, BHF]  [0.5, 0.5]
# 10        2   momentum120    [NKTR, HP]  [0.5, 0.5]
# 9         3   momentum120   [ABBV, OKE]  [0.5, 0.5]
# 14        4   momentum120    [GIS, MKC]  [0.5, 0.5]
# 16        5    momentum60   [CTAS, BLK]  [0.5, 0.5]
# 2         6  Buy and Hold   [CTAS, FLR]  [0.5, 0.5]
# 1         7  Buy and Hold   [RCL, EXPE]  [0.5, 0.5]
# 20        8    momentum60    [RRC, UAL]  [0.5, 0.5]
# 6         9  Buy and Hold    [ARNC, RE]  [0.5, 0.5]
# 18       10    momentum60    [ARNC, LB]  [0.5, 0.5]
# 5        11  Buy and Hold    [LB, ARNC]  [0.5, 0.5]
# 19       12    momentum60    [ARNC, LB]  [0.5, 0.5]
# 8        13  Buy and Hold      [M, GPS]  [0.5, 0.5]
# 17       14    momentum60   [DLTR, DFS]  [0.5, 0.5]
# 0        15  Buy and Hold  [ALXN, REGN]  [0.5, 0.5]
# 3        16  Buy and Hold    [EW, ARNC]  [0.5, 0.5]
# 7        17  Buy and Hold     [EW, GPS]  [0.5, 0.5]
# 15       18   momentum120      [M, DXC]  [0.5, 0.5]
# 4        19  Buy and Hold    [AAL, UAL]  [0.5, 0.5]
# 13       20   momentum120    [AAL, OXY]  [0.5, 0.5]
# 11       21   momentum120    [OXY, MAC]  [0.5, 0.5]

# %% [markdown]
# # 2. Realtime Trading Simulation

# %%
from lib import sparkStructuredStreaming

# object of class realtime
r = sparkStructuredStreaming.realtime()

# start capital in $
startCap = 10000

# number of companies in portfolio
portfolio_size = 2

# trading fee per share in $
commission = 0.006

# if sandbox = False -> stream real data from american stock markets
sandbox = False

r.realtime(startCap, portfolio_size, commission, sandbox, sqlContext)
# Out:
# 1. Find out which strategy worked best yesterday
#
# 2. Use that strategy to find stocks for today
#
# [*********************100%***********************]  456 of 456 completed
# [*********************100%***********************]  456 of 456 completed
# C:\Users\LEGLES\anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 3. Start Kafka Producer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e3b1f72c2bb9> in <module>
#      16 sandbox = False
#      17
# ---> 18 r.realtime(startCap, portfolio_size, commission, sandbox, sqlContext)
#
# ~\RAMBO\kafka_spark_python\lib\sparkStructuredStreaming.py in realtime(self, startCap, portfolio_size, commission, sandbox, sqlContext)
#    2039         subprocess.call(['producer_start.bat'])
#    2040
# -> 2041         time.sleep(5*10*len(symbol))
#    2042
#    2043         # get es ready
#
# KeyboardInterrupt:
